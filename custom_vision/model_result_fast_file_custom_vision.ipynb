# %%
import os
import requests

# === [Azure Custom Vision 설정] ===
prediction_key = "BBvYKDdr5RDpSMjG34Z2XXw3hLxzlAQkktCPXwHTLleSagQPHGg0JQQJ99BEACYeBjFXJ3w3AAAIACOGH9bC"
prediction_url = "https://7aiteam05cv-prediction.cognitiveservices.azure.com/customvision/v3.0/Prediction/4771ac4d-bd97-4521-af8e-861c385eca53/classify/iterations/Iteration5/image"

# === [예측할 이미지 폴더 경로] ===
image_folder = "iteration_5_test"  # 예: "C:/Users/USER/Desktop/images"

headers = {
    "Prediction-Key": prediction_key,
    "Content-Type": "application/octet-stream"
}

# === [이미지 반복 예측] ===
for filename in sorted(os.listdir(image_folder)):
    if not filename.lower().endswith(".jpg"):
        continue

    filepath = os.path.join(image_folder, filename)

    with open(filepath, "rb") as image_file:
        response = requests.post(prediction_url, headers=headers, data=image_file.read())

    if response.status_code == 200:
        predictions = response.json()["predictions"]
        top_pred = max(predictions, key=lambda x: x["probability"])
        print(f"📂 {filename} → 🧠 {top_pred['tagName']} ({top_pred['probability'] * 100:.1f}%)")
    else:
        print(f"❌ {filename} 예측 실패: {response.status_code}")
        print(response.json())

# %%
import os
import requests

# === [Azure Custom Vision 설정] ===
prediction_key = "BBvYKDdr5RDpSMjG34Z2XXw3hLxzlAQkktCPXwHTLleSagQPHGg0JQQJ99BEACYeBjFXJ3w3AAAIACOGH9bC"
prediction_url = "https://7aiteam05cv-prediction.cognitiveservices.azure.com/customvision/v3.0/Prediction/e81e8daf-2a54-4f41-9c8f-581d45e49ee9/detect/iterations/Iteration1/image"

# === [예측할 이미지 폴더 경로] ===
image_folder = "no-ciga"  # 예: "C:/Users/USER/Desktop/images"

headers = {
    "Prediction-Key": prediction_key,
    "Content-Type": "application/octet-stream"
}

# === [이미지 반복 예측] ===
for filename in sorted(os.listdir(image_folder)):
    if not filename.lower().endswith(".jpg"):
        continue

    filepath = os.path.join(image_folder, filename)

    with open(filepath, "rb") as image_file:
        response = requests.post(prediction_url, headers=headers, data=image_file.read())

    if response.status_code == 200:
        predictions = response.json()["predictions"]
        top_pred = max(predictions, key=lambda x: x["probability"])
        print(f"📂 {filename} → 🧠 {top_pred['tagName']} ({top_pred['probability'] * 100:.1f}%)")
    else:
        print(f"❌ {filename} 예측 실패: {response.status_code}")
        print(response.json())

# %%
import os
import requests

# === [Azure Custom Vision 설정] ===
prediction_key = "BBvYKDdr5RDpSMjG34Z2XXw3hLxzlAQkktCPXwHTLleSagQPHGg0JQQJ99BEACYeBjFXJ3w3AAAIACOGH9bC"
prediction_url = "https://7aiteam05cv-prediction.cognitiveservices.azure.com/customvision/v3.0/Prediction/e81e8daf-2a54-4f41-9c8f-581d45e49ee9/detect/iterations/Iteration3/image"

# === [예측할 이미지 폴더 경로] ===
image_folder = "no-ciga"  # 예: "C:/Users/USER/Desktop/images"

headers = {
    "Prediction-Key": prediction_key,
    "Content-Type": "application/octet-stream"
}

# === [이미지 반복 예측] ===
for filename in sorted(os.listdir(image_folder)):
    if not filename.lower().endswith(".jpg"):
        continue

    filepath = os.path.join(image_folder, filename)

    with open(filepath, "rb") as image_file:
        response = requests.post(prediction_url, headers=headers, data=image_file.read())

    if response.status_code == 200:
        predictions = response.json()["predictions"]
        top_pred = max(predictions, key=lambda x: x["probability"])
        print(f"📂 {filename} → 🧠 {top_pred['tagName']} ({top_pred['probability'] * 100:.1f}%)")
    else:
        print(f"❌ {filename} 예측 실패: {response.status_code}")
        print(response.json())
# Out:
# 📂 113636_103747_1847.jpg → 🧠 담배 (85.3%)
# 📂 1424371_4304_1906.jpg → 🧠 담배 (99.2%)
# 📂 1424371_4304_1906_aug_323c9263.jpg → 🧠 담배 (99.7%)
# 📂 16286_27233_5639.jpg → 🧠 담배 (83.1%)
# 📂 16286_27233_5639_aug_44ea6852.jpg → 🧠 담배 (94.4%)
# 📂 16286_27233_5639_aug_9aa870d1.jpg → 🧠 담배 (81.9%)
# 📂 2016042200057_1.jpg → 🧠 담배 (99.1%)
# 📂 2016042200057_1_aug_42828773.jpg → 🧠 담배 (95.0%)
# 📂 2016042200057_1_aug_ded75d3e.jpg → 🧠 담배 (96.5%)
# 📂 201720046_500.jpg → 🧠 담배 (94.7%)
# 📂 201720046_500_aug_3ce59449.jpg → 🧠 담배 (91.0%)
# 📂 201720046_500_aug_ac674c10.jpg → 🧠 담배 (97.0%)
# 📂 2017401_817407_3938.jpg → 🧠 담배 (96.0%)
# 📂 202102190146354380231-2-175912.jpg → 🧠 담배 (53.9%)
# 📂 202102190146354380231-2-175912_aug_0e970cf1.jpg → 🧠 담배 (5.2%)
# 📂 202102190146354380231-2-175912_aug_16f18b63.jpg → 🧠 담배 (28.8%)
# 📂 202102190146354380231-2-175912_aug_75ad6426.jpg → 🧠 담배 (58.5%)
# 📂 202102190146354380231-2-175912_aug_bc3a10eb.jpg → 🧠 담배 (50.2%)
# 📂 2022090516145068218_l.jpg → 🧠 담배 (83.1%)
# 📂 2022090516145068218_l_aug_167558fe.jpg → 🧠 담배 (98.6%)
# 📂 2022090516145068218_l_aug_1a0c4a19.jpg → 🧠 담배 (85.1%)
# 📂 20221113194418_20_906_1313114_1080_7.jpg → 🧠 담배 (82.4%)
# 📂 20221113194418_20_906_1313114_1080_7_aug_38f150f9.jpg → 🧠 담배 (89.6%)
# 📂 20221113194418_20_906_1313114_1080_7_aug_b2f46e86.jpg → 🧠 담배 (97.0%)
# 📂 20230619580160.jpg → 🧠 담배 (98.7%)
# 📂 20230619580160_aug_2d50e1a3.jpg → 🧠 담배 (98.8%)
# 📂 20230619580160_aug_77f63d2b.jpg → 🧠 담배 (98.9%)
# 📂 20240425502671.jpg → 🧠 담배 (72.6%)
# 📂 20240425502671_aug_a39e3654.jpg → 🧠 담배 (91.4%)
# 📂 20240425502671_aug_fbf853e5.jpg → 🧠 담배 (93.0%)
# 📂 20240613510775.jpg → 🧠 담배 (98.5%)
# 📂 2024071017095316699_2.jpg → 🧠 담배 (81.7%)
)
# 📂 SE-5487888b-ea4e-46a3-9ff4-ef6d59c046e2_aug_dd5aad50.jpg → 🧠 담배 (95.6%)
# 📂 SSC_20231117000337_O2.jpg → 🧠 담배 (97.1%)
# 📂 SSC_20231117000337_O2_aug_8789baf3.jpg → 🧠 담배 (9.8%)
# 📂 clean_04.jpg → 🧠 담배 (91.9%)
# ❌ clean_04_aug_0c00af9f.jpg 예측 실패: 400
# {'code': 'BadRequestImageSizeBytes', 'message': 'c845662ca87242d8af2b9810c15f7e79: 5772204/4194304 bytes'}
# ❌ clean_04_aug_37c12fb7.jpg 예측 실패: 400
# {'code': 'BadRequestImageSizeBytes', 'message': '7fe1a2a59d2c4e80b9b51acba2c9ec92: 5548563/4194304 bytes'}
# ❌ clean_04_aug_b4a8eecd.jpg 예측 실패: 400
# {'code': 'BadRequestImageSizeBytes', 'message': '374e48ea819649b49c349312352bd302: 5628844/4194304 bytes'}
# 📂 clean_120_001.jpg → 🧠 담배 (88.9%)
# 📂 clean_120_001_aug_4e4da501.jpg → 🧠 담배 (49.6%)
# 📂 clean_120_002.jpg → 🧠 담배 (15.3%)
# 📂 clean_120_002_aug_335bf25c.jpg → 🧠 담배 (94.2%)
# 📂 clean_120_003.jpg → 🧠 담배 (91.9%)
# ❌ clean_120_003_aug_259040f3.jpg 예측 실패: 400
# {'code': 'BadRequestImageSizeBytes', 'message': 'f0cbce2566bb4f5abcd8ef7b79074b0a: 5337221/4194304 bytes'}
# ❌ clean_120_003_aug_2f881961.jpg 예측 실패: 400
# {'code': 'BadRequestImageSizeBytes', 'message': '171ef02ff84f4887acc92ec0484a7c37: 5627719/4194304 bytes'}
# 📂 clean_120_014.jpg → 🧠 담배 (86.8%)
# 📂 clean_120_014_aug_38c969b4.jpg → 🧠 담배 (42.8%)
# 📂 clean_120_025.jpg → 🧠 담배 (80.4%)
# 📂 clean_120_025_aug_470c1807.jpg → 🧠 담배 (96.1%)
# 📂 clean_120_025_aug_9889fae8.jpg → 🧠 담배 (88.7%)
# 📂 clean_120_025_aug_d5e408b7.jpg → 🧠 담배 (76.3%)
# ❌ clean_120_025_aug_e14477fb.jpg 예측 실패: 400
# {'code': 'BadRequestImageSizeBytes', 'message': '59d82ef4bf2f436f8d1e7f44224b4f01: 4482569/4194304 bytes'}
# 📂 clean_120_038.jpg → 🧠 담배 (94.5%)
# 📂 clean_120_038_aug_83dfadf5.jpg → 🧠 담배 (96.2%)
# 📂 clean_120_078.jpg → 🧠 담배 (51.0%)
# 📂 clean_120_080.jpg → 🧠 담배 (46.7%)
# 📂 clean_120_081.jpg → 🧠 담배 (18.7%)
# 📂 clean_120_090.jpg → 🧠 담배 (61.4%)
# 📂 clean_120_093.jpg → 🧠 담배 (40.3%)
# 📂 clean_120_093_aug_52ce538c.jpg → 🧠 담배 (57.8%)
# 📂 clean_120_096.jpg → 🧠 담배 (23.0%)
# 📂 clean_120_096_aug_346a0c0f.jpg → 🧠 담배 (28.3%)
# 📂 clean_120_100.jpg → 🧠 담배 (81.8%)
# 📂 clean_120_100_aug_6bc91931.jpg → 🧠 담배 (93.7%)
# 📂 clean_120_100_aug_cbc4e7d5.jpg → 🧠 담배 (91.0%)
# 📂 clean_120_102.jpg → 🧠 담배 (91.2%)
# 📂 clean_120_102_aug_4a0d8d11.jpg → 🧠 담배 (31.7%)
# 📂 clean_120_118.jpg → 🧠 담배 (59.6%)
# 📂 clean_120_118_aug_20c1f45e.jpg → 🧠 담배 (95.6%)
# 📂 clean_120_120.jpg → 🧠 담배 (63.6%)
# 📂 clean_120_120_aug_2a0e2cc3.jpg → 🧠 담배 (13.8%)
# 📂 clean_120_120_aug_bb817d04.jpg → 🧠 담배 (92.9%)
# 📂 clean_23.jpg → 🧠 담배 (99.2%)
# ❌ clean_23_aug_00e05f08.jpg 예측 실패: 400
# {'code': 'BadRequestImageSizeBytes', 'message': 'a47a1144ed39434fa438a3bbf821dd68: 7843555/4194304 bytes'}
# 📂 clean_23_aug_4304a42f.jpg → 🧠 담배 (99.6%)
# 📂 clean_23_aug_c0c81c54.jpg → 🧠 담배 (99.7%)
# 📂 clean_64.jpg → 🧠 담배 (95.0%)
# 📂 clean_64_aug_d4719e78.jpg → 🧠 담배 (91.3%)
# 📂 clean_69.jpg → 🧠 담배 (78.3%)
# 📂 clean_69_aug_0504498d.jpg → 🧠 담배 (80.4%)
# 📂 clean_72.jpg → 🧠 담배 (99.2%)
# ❌ clean_72_aug_19cc618c.jpg 예측 실패: 400
# {'code': 'BadRequestImageSizeBytes', 'message': '47f85794c80c44709076e9b3159a6186: 8705497/4194304 bytes'}
# 📂 clean_72_aug_3f3735dd.jpg → 🧠 담배 (98.8%)
# 📂 clean_72_aug_4b6411bc.jpg → 🧠 담배 (98.8%)
# 📂 clean_72_aug_f45ca927.jpg → 🧠 담배 (97.9%)
# 📂 clean_73.jpg → 🧠 담배 (97.2%)
# 📂 clean_73_aug_103b4ea1.jpg → 🧠 담배 (58.7%)
# 📂 dfszefewfefa (1).jpg → 🧠 담배 (99.4%)
# 📂 dfszefewfefa (10).jpg → 🧠 담배 (64.5%)
# 📂 dfszefewfefa (11).jpg → 🧠 담배 (83.8%)
# 📂 dfszefewfefa (12).jpg → 🧠 담배 (54.9%)
# 📂 dfszefewfefa (13).jpg → 🧠 담배 (97.7%)
# 📂 dfszefewfefa (14).jpg → 🧠 담배 (68.7%)
# 📂 dfszefewfefa (15).jpg → 🧠 담배 (67.9%)
# 📂 dfszefewfefa (16).jpg → 🧠 담배 (99.7%)
# 📂 dfszefewfefa (17).jpg → 🧠 담배 (98.1%)
# 📂 dfszefewfefa (18).jpg → 🧠 담배 (99.2%)
# 📂 dfszefewfefa (19).jpg → 🧠 담배 (38.9%)
# 📂 dfszefewfefa (2).jpg → 🧠 담배 (89.8%)
# 📂 dfszefewfefa (20).jpg → 🧠 담배 (87.9%)
# 📂 dfszefewfefa (21).jpg → 🧠 담배 (72.1%)
# 📂 dfszefewfefa (22).jpg → 🧠 담배 (96.9%)
# 📂 dfszefewfefa (23).jpg → 🧠 담배 (97.0%)
# 📂 dfszefewfefa (24).jpg → 🧠 담배 (66.8%)
# 📂 dfszefewfefa (25).jpg → 🧠 담배 (90.4%)
# 📂 dfszefewfefa (26).jpg → 🧠 담배 (85.4%)
# 📂 dfszefewfefa (3).jpg → 🧠 담배 (87.9%)
# 📂 dfszefewfefa (4).jpg → 🧠 담배 (97.6%)
# 📂 dfszefewfefa (5).jpg → 🧠 담배 (99.7%)
# 📂 dfszefewfefa (6).jpg → 🧠 담배 (99.8%)
# 📂 dfszefewfefa (7).jpg → 🧠 담배 (90.7%)
# 📂 dfszefewfefa (8).jpg → 🧠 담배 (91.3%)
# 📂 dfszefewfefa (9).jpg → 🧠 담배 (89.2%)
# 📂 e73b05be-6ac6-4a78-b177-45c151b59a74.jpg → 🧠 담배 (84.2%)
# 📂 e73b05be-6ac6-4a78-b177-45c151b59a74_aug_34203852.jpg → 🧠 담배 (72.3%)
# 📂 e73b05be-6ac6-4a78-b177-45c151b59a74_aug_8e8827db.jpg → 🧠 담배 (92.4%)
# 📂 heavy_17.jpg → 🧠 담배 (98.7%)
# 📂 heavy_17_aug_3b76e974.jpg → 🧠 담배 (84.6%)
# 📂 heavy_17_aug_5a60f65c.jpg → 🧠 담배 (99.5%)
# 📂 heavy_17_aug_ea216258.jpg → 🧠 담배 (94.6%)
# 📂 image02.jpg → 🧠 담배 (82.6%)
# 📂 image02_aug_5af3d59c.jpg → 🧠 담배 (89.0%)
# 📂 image02_aug_63c352fc.jpg → 🧠 담배 (51.9%)
# 📂 image02_aug_b1df1b27.jpg → 🧠 담배 (88.9%)
# 📂 istockphoto-483166525-612x612.jpg → 🧠 담배 (84.4%)
# 📂 istockphoto-483166525-612x612_aug_08fa5bdc.jpg → 🧠 담배 (96.1%)
# 📂 istockphoto-483166525-612x612_aug_579823f2.jpg → 🧠 담배 (74.4%)
# 📂 istockphoto-483166525-612x612_aug_5b2ccb6b.jpg → 🧠 담배 (56.7%)
# 📂 istockphoto-483166525-612x612_aug_67b4b87e.jpg → 🧠 담배 (63.0%)
# 📂 maxresdefault (1).jpg → 🧠 담배 (97.0%)
# 📂 maxresdefault (1)_aug_22cc0de5.jpg → 🧠 담배 (89.9%)
# 📂 maxresdefault.jpg → 🧠 담배 (17.3%)
# 📂 md_1f2084bbeb.jpg → 🧠 담배 (77.9%)
# 📂 md_1f2084bbeb_aug_298be73c.jpg → 🧠 담배 (93.9%)
# 📂 md_1f2084bbeb_aug_8d9abcff.jpg → 🧠 담배 (97.7%)
# 📂 md_1f2084bbeb_aug_90378db3.jpg → 🧠 담배 (66.3%)
# 📂 medium_clean_003.jpg → 🧠 담배 (82.2%)
# 📂 medium_clean_003_aug_61693cc4.jpg → 🧠 담배 (70.8%)
# 📂 medium_clean_003_aug_708e9a89.jpg → 🧠 담배 (88.7%)
# 📂 medium_clean_003_aug_aa41b648.jpg → 🧠 담배 (93.5%)
# 📂 medium_clean_003_aug_bfbbd7fa.jpg → 🧠 담배 (99.2%)
# 📂 medium_clean_003_aug_f798456c.jpg → 🧠 담배 (79.1%)
# 📂 medium_clean_032.jpg → 🧠 담배 (62.5%)
# 📂 medium_clean_032_aug_85471c7a.jpg → 🧠 담배 (49.7%)
# 📂 medium_clean_032_aug_974804a8.jpg → 🧠 담배 (26.2%)
# ❌ medium_clean_032_aug_c0f777f0.jpg 예측 실패: 400
# {'code': 'BadRequestImageSizeBytes', 'message': '5afbfc1830174069ab5e2c106472c3f2: 10081219/4194304 bytes'}
# 📂 medium_clean_042.jpg → 🧠 담배 (98.3%)
# 📂 medium_clean_042_aug_2c665815.jpg → 🧠 담배 (97.0%)
# 📂 medium_clean_058.jpg → 🧠 담배 (99.7%)
# ❌ medium_clean_058_aug_5324029d.jpg 예측 실패: 400
# {'code': 'BadRequestImageSizeBytes', 'message': 'd8334e5447c246e39266be8b2e9b6f18: 4712471/4194304 bytes'}
# 📂 medium_clean_059.jpg → 🧠 담배 (98.4%)
# ❌ medium_clean_059_aug_99b9517c.jpg 예측 실패: 400
# {'code': 'BadRequestImageSizeBytes', 'message': 'c4597b4aa489484d9fc08980059e0b53: 4229174/4194304 bytes'}
# 📂 medium_clean_060.jpg → 🧠 담배 (59.8%)
# 📂 medium_clean_061.jpg → 🧠 담배 (7.4%)
# 📂 medium_clean_061_aug_d47080c8.jpg → 🧠 담배 (44.0%)
# 📂 medium_clean_066.jpg → 🧠 담배 (29.6%)
# 📂 medium_clean_079.jpg → 🧠 담배 (97.8%)
# 📂 medium_clean_079_aug_09f65c44.jpg → 🧠 담배 (98.8%)
# 📂 medium_clean_079_aug_adca3bf0.jpg → 🧠 담배 (98.6%)
# 📂 medium_clean_169.jpg → 🧠 담배 (99.9%)
# 📂 medium_clean_169_aug_5b0ac7f4.jpg → 🧠 담배 (99.7%)
# 📂 medium_clean_172.jpg → 🧠 담배 (89.0%)
# 📂 medium_clean_172_aug_7311f653.jpg → 🧠 담배 (37.4%)
# 📂 medium_clean_172_aug_7ecdb126.jpg → 🧠 담배 (79.7%)
# 📂 medium_clean_180.jpg → 🧠 담배 (95.5%)
# 📂 medium_clean_180_aug_1d090514.jpg → 🧠 담배 (97.4%)
# 📂 medium_clean_226.jpg → 🧠 담배 (96.3%)
# 📂 medium_clean_226_aug_106da0e0.jpg → 🧠 담배 (88.9%)
# 📂 medium_clean_226_aug_a8c9c329.jpg → 🧠 담배 (95.8%)
# 📂 medium_clean_226_aug_ac10608d.jpg → 🧠 담배 (86.1%)
# 📂 medium_clean_226_aug_e4987a6a.jpg → 🧠 담배 (94.9%)
# 📂 medium_clean_250.jpg → 🧠 담배 (66.2%)
# 📂 medium_clean_250_aug_52b855a7.jpg → 🧠 담배 (64.3%)
# 📂 medium_clean_250_aug_54e74b1c.jpg → 🧠 담배 (62.8%)
# 📂 medium_clean_252.jpg → 🧠 담배 (99.5%)
# 📂 medium_clean_252_aug_01cc6391.jpg → 🧠 담배 (94.1%)
# 📂 medium_clean_252_aug_1b259c99.jpg → 🧠 담배 (86.0%)
# 📂 medium_clean_252_aug_413e3e79.jpg → 🧠 담배 (99.0%)
# 📂 medium_clean_252_aug_903c9773.jpg → 🧠 담배 (24.5%)
# 📂 medium_clean_252_aug_bea450af.jpg → 🧠 담배 (89.4%)
# 📂 medium_clean_267.jpg → 🧠 담배 (99.9%)
# ❌ medium_clean_267_aug_681c6dc0.jpg 예측 실패: 400
# {'code': 'BadRequestImageSizeBytes', 'message': '25863f69d05343b2b2f1e5be73bbcced: 5032153/4194304 bytes'}
# ❌ medium_clean_267_aug_8d52c253.jpg 예측 실패: 400
# {'code': 'BadRequestImageSizeBytes', 'message': '5b77c4f0a8ff4e2f842c4e88a8756afa: 5489624/4194304 bytes'}
# ❌ medium_clean_267_aug_9fe57673.jpg 예측 실패: 400
# {'code': 'BadRequestImageSizeBytes', 'message': '9a37b61bdec64048908dc89c6d75b00f: 5768502/4194304 bytes'}
# ❌ medium_clean_267_aug_fb1a1ee0.jpg 예측 실패: 400
# {'code': 'BadRequestImageSizeBytes', 'message': '82990f2b156b44e8b96e3e088f74b321: 5289674/4194304 bytes'}
# 📂 medium_clean_274.jpg → 🧠 담배 (95.2%)
# ❌ medium_clean_274_aug_d58176b0.jpg 예측 실패: 400
# {'code': 'BadRequestImageSizeBytes', 'message': 
# 📂 news-p.v1.20231115.a92a83b277bc4f0c82fcd6203b6fc7e5_P2_aug_3e3cf7e1.jpg → 🧠 담배 (22.7%)
# 📂 news-p.v1.20231115.a92a83b277bc4f0c82fcd6203b6fc7e5_P2_aug_8438aec5.jpg → 🧠 담배 (90.8%)
# 📂 news_1688621280_1250697_m_1.jpg → 🧠 담배 (96.9%)
# 📂 news_1688621280_1250697_m_1_aug_6c00966d.jpg → 🧠 담배 (91.5%)
# 📂 news_1718603323_1372659_m_3.jpg → 🧠 담배 (90.5%)
# 📂 news_1718603323_1372659_m_3_aug_b1e5f04f.jpg → 🧠 담배 (63.7%)
# 📂 sosp_KV_17888_20240826_110634.jpg → 🧠 담배 (24.6%)
# 📂 sosp_KV_17888_20240826_110634_aug_6dcfc22b.jpg → 🧠 담배 (41.0%)
# 📂 sosp_KV_17888_20240826_110634_aug_e83428b9.jpg → 🧠 담배 (91.9%)
# 📂 sosp_KV_25051_20240707_170406.jpg → 🧠 담배 (58.4%)
# 📂 sosp_KV_25051_20240707_170406_aug_0df7caa4.jpg → 🧠 담배 (60.7%)
# 📂 sosp_KV_25051_20240707_170406_aug_f2346455.jpg → 🧠 담배 (95.1%)
# 📂 sosp_KV_25866_20240831_194055.jpg → 🧠 담배 (90.9%)
# 📂 sosp_KV_25866_20240831_194055_aug_29090386.jpg → 🧠 담배 (96.1%)
# 📂 thumb_d_BCDE1B716DC67E11916D9B699C794B20.jpg → 🧠 담배 (97.2%)
# 📂 thumb_d_BCDE1B716DC67E11916D9B699C794B20_aug_54b2135b.jpg → 🧠 담배 (99.4%)
# 📂 thumb_d_BCDE1B716DC67E11916D9B699C794B20_aug_afe8d99d.jpg → 🧠 담배 (89.8%)
# 📂 thumb_d_BCDE1B716DC67E11916D9B699C794B20_aug_c2460a4e.jpg → 🧠 담배 (99.5%)
# 📂 다운로드 (1).jpg → 🧠 담배 (99.2%)
# 📂 다운로드 (10).jpg → 🧠 담배 (99.7%)
# 📂 다운로드 (11).jpg → 🧠 담배 (39.1%)
# 📂 다운로드 (12).jpg → 🧠 담배 (99.8%)
# 📂 다운로드 (13).jpg → 🧠 담배 (73.0%)
# 📂 다운로드 (14).jpg → 🧠 담배 (88.1%)
# 📂 다운로드 (15).jpg → 🧠 담배 (90.9%)
# 📂 다운로드 (16).jpg → 🧠 담배 (99.1%)
# 📂 다운로드 (17).jpg → 🧠 담배 (99.3%)
# 📂 다운로드 (18).jpg → 🧠 담배 (99.9%)
# 📂 다운로드 (19).jpg → 🧠 담배 (99.8%)
# 📂 다운로드 (2).jpg → 🧠 담배 (98.4%)
# 📂 다운로드 (20).jpg → 🧠 담배 (99.3%)
# 📂 다운로드 (21).jpg → 🧠 담배 (96.3%)
# 📂 다운로드 (22).jpg → 🧠 담배 (42.5%)
# 📂 다운로드 (23).jpg → 🧠 담배 (98.2%)
# 📂 다운로드 (24).jpg → 🧠 담배 (98.9%)
# 📂 다운로드 (25).jpg → 🧠 담배 (77.9%)
# 📂 다운로드 (26).jpg → 🧠 담배 (88.9%)
# 📂 다운로드 (28).jpg → 🧠 담배 (59.2%)
# 📂 다운로드 (29).jpg → 🧠 담배 (16.7%)
# 📂 다운로드 (3).jpg → 🧠 담배 (17.8%)
# 📂 다운로드 (31).jpg → 🧠 담배 (93.0%)
# 📂 다운로드 (32).jpg → 🧠 담배 (83.3%)
# 📂 다운로드 (33).jpg → 🧠 담배 (96.7%)
# 📂 다운로드 (34).jpg → 🧠 담배 (15.4%)
# 📂 다운로드 (35).jpg → 🧠 담배 (99.3%)
# 📂 다운로드 (36).jpg → 🧠 담배 (13.0%)
# 📂 다운로드 (37).jpg → 🧠 담배 (18.2%)
# 📂 다운로드 (38).jpg → 🧠 담배 (31.0%)
# 📂 다운로드 (39).jpg → 🧠 담배 (84.3%)
# 📂 다운로드 (4).jpg → 🧠 담배 (99.9%)
# 📂 다운로드 (40).jpg → 🧠 담배 (91.4%)
# 📂 다운로드 (41).jpg → 🧠 담배 (74.9%)
# 📂 다운로드 (42).jpg → 🧠 담배 (95.5%)
# 📂 다운로드 (5).jpg → 🧠 담배 (90.7%)
# 📂 다운로드 (6).jpg → 🧠 담배 (97.9%)
# 📂 다운로드 (7).jpg → 🧠 담배 (99.7%)
# 📂 다운로드 (8).jpg → 🧠 담배 (98.8%)
# 📂 다운로드 (9).jpg → 🧠 담배 (46.2%)
# 📂 다운로드.jpg → 🧠 담배 (98.9%)
# 📂 사진_001.jpg → 🧠 담배 (66.3%)
# 📂 스크린샷 2025-06-11 214317.jpg → 🧠 담배 (94.7%)
# 📂 스크린샷 2025-06-11 220638.jpg → 🧠 담배 (99.0%)

# %%
# iteration 4
import os
import requests

# === [Azure Custom Vision 설정] ===
prediction_key = "BBvYKDdr5RDpSMjG34Z2XXw3hLxzlAQkktCPXwHTLleSagQPHGg0JQQJ99BEACYeBjFXJ3w3AAAIACOGH9bC"
prediction_url = "https://7aiteam05cv-prediction.cognitiveservices.azure.com/customvision/v3.0/Prediction/e81e8daf-2a54-4f41-9c8f-581d45e49ee9/detect/iterations/Iteration5/image"

# === [예측할 이미지 폴더 경로] ===
image_folder = "no-ciga"  # 예: "C:/Users/USER/Desktop/images"

headers = {
    "Prediction-Key": prediction_key,
    "Content-Type": "application/octet-stream"
}

# === [이미지 반복 예측] ===
for filename in sorted(os.listdir(image_folder)):
    if not filename.lower().endswith(".jpg"):
        continue

    filepath = os.path.join(image_folder, filename)

    with open(filepath, "rb") as image_file:
        response = requests.post(prediction_url, headers=headers, data=image_file.read())

    if response.status_code == 200:
        predictions = response.json()["predictions"]
        top_pred = max(predictions, key=lambda x: x["probability"])
        print(f"📂 {filename} → 🧠 {top_pred['tagName']} ({top_pred['probability'] * 100:.1f}%)")
    else:
        print(f"❌ {filename} 예측 실패: {response.status_code}")
        print(response.json())
# Out:
# 📂 113636_103747_1847.jpg → 🧠 담배 (38.1%)
# 📂 1424371_4304_1906.jpg → 🧠 담배 (97.5%)
# 📂 1424371_4304_1906_aug_323c9263.jpg → 🧠 담배 (99.4%)
# 📂 16286_27233_5639.jpg → 🧠 담배 (49.5%)
# 📂 16286_27233_5639_aug_44ea6852.jpg → 🧠 담배 (96.9%)
# 📂 16286_27233_5639_aug_9aa870d1.jpg → 🧠 담배 (49.0%)
.jpg 예측 실패: 400
# {'code': 'BadRequestImageSizeBytes', 'message': 'e390403d86244e248b10f2732fcfd34f: 5337221/4194304 bytes'}
# ❌ clean_120_003_aug_2f881961.jpg 예측 실패: 400
# {'code': 'BadRequestImageSizeBytes', 'message': '6311b2ad63664794bfce6cbba59b8d7e: 5627719/4194304 bytes'}
# 📂 clean_120_014.jpg → 🧠 담배 (14.3%)
# 📂 clean_120_014_aug_38c969b4.jpg → 🧠 담배 (11.7%)
# 📂 clean_120_025.jpg → 🧠 담배 (95.9%)
# 📂 clean_120_025_aug_470c1807.jpg → 🧠 담배 (96.6%)
# 📂 clean_120_025_aug_9889fae8.jpg → 🧠 담배 (93.7%)
# 📂 clean_120_025_aug_d5e408b7.jpg → 🧠 담배 (96.8%)
# ❌ clean_120_025_aug_e14477fb.jpg 예측 실패: 400
# {'code': 'BadRequestImageSizeBytes', 'message': 'c167da187f7f4ad1bb72e739058c9127: 4482569/4194304 bytes'}
# 📂 clean_120_038.jpg → 🧠 담배 (98.0%)
# 📂 clean_120_038_aug_83dfadf5.jpg → 🧠 담배 (91.5%)
# 📂 clean_120_078.jpg → 🧠 담배 (91.0%)
# 📂 clean_120_080.jpg → 🧠 담배 (28.0%)
# 📂 clean_120_081.jpg → 🧠 담배 (23.5%)
# 📂 clean_120_090.jpg → 🧠 담배 (31.2%)
# 📂 clean_120_093.jpg → 🧠 담배 (96.9%)
# 📂 clean_120_093_aug_52ce538c.jpg → 🧠 담배 (98.8%)
# 📂 clean_120_096.jpg → 🧠 담배 (9.8%)
# 📂 clean_120_096_aug_346a0c0f.jpg → 🧠 담배 (63.3%)
# 📂 clean_120_100.jpg → 🧠 담배 (75.7%)
# 📂 clean_120_100_aug_6bc91931.jpg → 🧠 담배 (93.6%)
# 📂 clean_120_100_aug_cbc4e7d5.jpg → 🧠 담배 (56.7%)
# 📂 clean_120_102.jpg → 🧠 담배 (85.6%)
# 📂 clean_120_102_aug_4a0d8d11.jpg → 🧠 담배 (16.9%)
# 📂 clean_120_118.jpg → 🧠 담배 (31.3%)
# 📂 clean_120_118_aug_20c1f45e.jpg → 🧠 담배 (69.9%)
# 📂 clean_120_120.jpg → 🧠 담배 (27.9%)
# 📂 clean_120_120_aug_2a0e2cc3.jpg → 🧠 담배 (62.3%)
# 📂 clean_120_120_aug_bb817d04.jpg → 🧠 담배 (32.6%)
# 📂 clean_23.jpg → 🧠 담배 (99.5%)
# ❌ clean_23_aug_00e05f08.jpg 예측 실패: 400
# {'code': 'BadRequestImageSizeBytes', 'message': 'ca624f5a181e4dacbf5344e431cc0159: 7843555/4194304 bytes'}
# 📂 clean_23_aug_4304a42f.jpg → 🧠 담배 (99.5%)
# 📂 clean_23_aug_c0c81c54.jpg → 🧠 담배 (99.6%)
# 📂 clean_64.jpg → 🧠 담배 (82.0%)
# 📂 clean_64_aug_d4719e78.jpg → 🧠 담배 (92.5%)
# 📂 clean_69.jpg → 🧠 담배 (97.3%)
# 📂 clean_69_aug_0504498d.jpg → 🧠 담배 (86.2%)
# 📂 clean_72.jpg → 🧠 담배 (96.8%)
# ❌ clean_72_aug_19cc618c.jpg 예측 실패: 400
# {'code': 'BadRequestImageSizeBytes', 'message': '96079b25e6da486f87ed6db0f8e3e9e7: 8705497/4194304 bytes'}
# 📂 clean_72_aug_3f3735dd.jpg → 🧠 담배 (89.7%)
# 📂 clean_72_aug_4b6411bc.jpg → 🧠 담배 (99.0%)
# 📂 clean_72_aug_f45ca927.jpg → 🧠 담배 (72.8%)
# 📂 clean_73.jpg → 🧠 담배 (88.4%)
# 📂 clean_73_aug_103b4ea1.jpg → 🧠 담배 (93.1%)
# 📂 dfszefewfefa (1).jpg → 🧠 담배 (96.4%)
# 📂 dfszefewfefa (10).jpg → 🧠 담배 (97.4%)
# 📂 dfszefewfefa (11).jpg → 🧠 담배 (98.2%)
# 📂 dfszefewfefa (12).jpg → 🧠 담배 (99.8%)
# 📂 dfszefewfefa (13).jpg → 🧠 담배 (99.3%)
# 📂 dfszefewfefa (14).jpg → 🧠 담배 (89.3%)
# 📂 dfszefewfefa (15).jpg → 🧠 담배 (34.4%)
# 📂 dfszefewfefa (16).jpg → 🧠 담배 (97.1%)
# 📂 dfszefewfefa (17).jpg → 🧠 담배 (74.2%)
# 📂 dfszefewfefa (18).jpg → 🧠 담배 (19.3%)
# 📂 dfszefewfefa (19).jpg → 🧠 담배 (64.4%)
# 📂 dfszefewfefa (2).jpg → 🧠 담배 (55.9%)
# 📂 dfszefewfefa (20).jpg → 🧠 담배 (96.9%)
# 📂 dfszefewfefa (21).jpg → 🧠 담배 (89.2%)
# 📂 dfszefewfefa (22).jpg → 🧠 담배 (12.5%)
# 📂 dfszefewfefa (23).jpg → 🧠 담배 (88.5%)
# 📂 dfszefewfefa (24).jpg → 🧠 담배 (91.2%)
# 📂 dfszefewfefa (25).jpg → 🧠 담배 (62.2%)
# 📂 dfszefewfefa (26).jpg → 🧠 담배 (69.2%)
# 📂 dfszefewfefa (3).jpg → 🧠 담배 (91.1%)
# 📂 dfszefewfefa (4).jpg → 🧠 담배 (92.2%)
# 📂 dfszefewfefa (5).jpg → 🧠 담배 (97.4%)
# 📂 dfszefewfefa (6).jpg → 🧠 담배 (98.8%)
# 📂 dfszefewfefa (7).jpg → 🧠 담배 (78.9%)
# 📂 dfszefewfefa (8).jpg → 🧠 담배 (97.5%)
# 📂 dfszefewfefa (9).jpg → 🧠 담배 (90.4%)
# 📂 e73b05be-6ac6-4a78-b177-45c151b59a74.jpg → 🧠 담배 (89.3%)
# 📂 e73b05be-6ac6-4a78-b177-45c151b59a74_aug_34203852.jpg → 🧠 담배 (70.6%)
# 📂 e73b05be-6ac6-4a78-b177-45c151b59a74_aug_8e8827db.jpg → 🧠 담배 (94.4%)
# 📂 heavy_17.jpg → 🧠 담배 (98.9%)
# 📂 heavy_17_aug_3b76e974.jpg → 🧠 담배 (98.7%)
# 📂 heavy_17_aug_5a60f65c.jpg → 🧠 담배 (98.7%)
# 📂 heavy_17_aug_ea216258.jpg → 🧠 담배 (98.6%)
# 📂 image02.jpg → 🧠 담배 (46.2%)
# 📂 image02_aug_5af3d59c.jpg → 🧠 담배 (38.7%)
# 📂 image02_aug_63c352fc.jpg → 🧠 담배 (23.5%)
# 📂 image02_aug_b1df1b27.jpg → 🧠 담배 (62.8%)
# 📂 istockphoto-483166525-612x612.jpg → 🧠 담배 (36.2%)
# 📂 istockphoto-483166525-612x612_aug_08fa5bdc.jpg → 🧠 담배 (23.9%)
# 📂 istockphoto-483166525-612x612_aug_579823f2.jpg → 🧠 담배 (44.2%)
# 📂 istockphoto-483166525-612x612_aug_5b2ccb6b.jpg → 🧠 담배 (26.9%)
# 📂 istockphoto-483166525-612x612_aug_67b4b87e.jpg → 🧠 담배 (41.4%)
# 📂 maxresdefault (1).jpg → 🧠 담배 (98.4%)
# 📂 maxresdefault (1)_aug_22cc0de5.jpg → 🧠 담배 (62.2%)
# 📂 maxresdefault.jpg → 🧠 담배 (32.3%)
# 📂 md_1f2084bbeb.jpg → 🧠 담배 (88.9%)
# 📂 md_1f2084bbeb_aug_298be73c.jpg → 🧠 담배 (84.8%)
# 📂 md_1f2084bbeb_aug_8d9abcff.jpg → 🧠 담배 (77.4%)
# 📂 md_1f2084bbeb_aug_90378db3.jpg → 🧠 담배 (95.2%)
# 📂 medium_clean_003.jpg → 🧠 담배 (61.6%)
# 📂 medium_clean_003_aug_61693cc4.jpg → 🧠 담배 (72.1%)
# 📂 medium_clean_003_aug_708e9a89.jpg → 🧠 담배 (69.9%)
# 📂 medium_clean_003_aug_aa41b648.jpg → 🧠 담배 (33.1%)
# 📂 medium_clean_003_aug_bfbbd7fa.jpg → 🧠 담배 (54.7%)
# 📂 medium_clean_003_aug_f798456c.jpg → 🧠 담배 (9.8%)
# 📂 medium_clean_032.jpg → 🧠 담배 (3.7%)
# 📂 medium_clean_032_aug_85471c7a.jpg → 🧠 담배 (94.0%)
# 📂 medium_clean_032_aug_974804a8.jpg → 🧠 담배 (18.5%)
# ❌ medium_clean_032_aug_c0f777f0.jpg 예측 실패: 400
# {'code': 'BadRequestImageSizeBytes', 'message': 'd8be81d440794f369ffe7b782960f5ad: 10081219/4194304 bytes'}
# 📂 medium_clean_042.jpg → 🧠 담배 (92.3%)
# 📂 medium_clean_042_aug_2c665815.jpg → 🧠 담배 (99.9%)
# 📂 medium_clean_058.jpg → 🧠 담배 (82.1%)
# ❌ medium_clean_058_aug_5324029d.jpg 예측 실패: 400
# {'code': 'BadRequestImageSizeBytes', 'message': 'bfeb74cad6244b199073c5d17fc09ea7: 4712471/4194304 bytes'}
# 📂 medium_clean_059.jpg → 🧠 담배 (96.9%)
# ❌ medium_clean_059_aug_99b9517c.jpg 예측 실패: 400
# {'code': 'BadRequestImageSizeBytes', 'message': 'f1f89135b5fa42939873c4bf882e7ade: 4229174/4194304 bytes'}
# 📂 medium_clean_060.jpg → 🧠 담배 (76.1%)
# 📂 medium_clean_061.jpg → 🧠 담배 (4.0%)
# 📂 medium_clean_061_aug_d47080c8.jpg → 🧠 담배 (15.5%)
# 📂 medium_clean_066.jpg → 🧠 담배 (24.5%)
# 📂 medium_clean_079.jpg → 🧠 담배 (95.7%)
# 📂 medium_clean_079_aug_09f65c44.jpg → 🧠 담배 (97.4%)
# 📂 medium_clean_079_aug_adca3bf0.jpg → 🧠 담배 (95.3%)
# 📂 medium_clean_169.jpg → 🧠 담배 (99.7%)
# 📂 medium_clean_169_aug_5b0ac7f4.jpg → 🧠 담배 (95.5%)
# 📂 medium_clean_172.jpg → 🧠 담배 (96.7%)
# 📂 medium_clean_172_aug_7311f653.jpg → 🧠 담배 (86.4%)
# 📂 medium_clean_172_aug_7ecdb126.jpg → 🧠 담배 (79.4%)
# 📂 medium_clean_180.jpg → 🧠 담배 (93.8%)
# 📂 medium_clean_180_aug_1d090514.jpg → 🧠 담배 (80.2%)
# 📂 medium_clean_226.jpg → 🧠 담배 (93.3%)
# 📂 medium_clean_226_aug_106da0e0.jpg → 🧠 담배 (91.8%)
# 📂 medium_clean_226_aug_a8c9c329.jpg → 🧠 담배 (99.4%)
# 📂 medium_clean_226_aug_ac10608d.jpg → 🧠 담배 (94.5%)
# 📂 medium_clean_226_aug_e4987a6a.jpg → 🧠 담배 (96.9%)
# 📂 medium_clean_250.jpg → 🧠 담배 (43.8%)
# 📂 medium_clean_250_aug_52b855a7.jpg → 🧠 담배 (64.6%)
# 📂 medium_clean_250_aug_54e74b1c.jpg → 🧠 담배 (9.8%)
# 📂 medium_clean_252.jpg → 🧠 담배 (97.8%)
# 📂 medium_clean_252_aug_01cc6391.jpg → 🧠 담배 (89.0%)
# 📂 medium_clean_252_aug_1b259c99.jpg → 🧠 담배 (40.0%)
# 📂 medium_clean_252_aug_413e3e79.jpg → 🧠 담배 (28.6%)
# 📂 medium_clean_252_aug_903c9773.jpg → 🧠 담배 (59.0%)
# 📂 medium_clean_252_aug_bea450af.jpg → 🧠 담배 (94.6%)
# 📂 medium_clean_267.jpg → 🧠 담배 (99.6%)
# ❌ medium_clean_267_aug_681c6dc0.jpg 예측 실패: 400
# {'code': 'BadRequestImageSizeBytes', 'message': '7b2481f7783d4b5f9177e7b1100c4e7a: 5032153/4194304 bytes'}
# ❌ medium_clean_267_aug_8d52c253.jpg 예측 실패: 400
# {'code': 'BadRequestImageSizeBytes', 'message': 'e436111830704ad6bd1bac8e962b8995: 5489624/4194304 bytes'}
# ❌ medium_clean_267_aug_9fe57673.jpg 예측 실패: 400
# {'code': 'BadRequestImageSizeBytes', 'message': '1f086725b64b49dfa0ac395e94eb0476: 5768502/4194304 bytes'}
# ❌ medium_clean_267_aug_fb1a1ee0.jpg 예측 실패: 400
# {'code': 'BadRequestImageSizeBytes', 'message': '48cda1f20d1b48019a721361c657318e: 5289674/4194304 bytes'}
# 📂 medium_clean_274.jpg → 🧠 담배 (94.6%)
# ❌ medium_clean_274_aug_d58176b0.jpg 예측 실패: 400
# {'code': 'BadRequestImageSizeBytes', 'message': 'c1e4a695207d4c848d49dc913fc6673d: 5738612/4194304 bytes'}
# 📂 medium_clean_278.jpg → 🧠 담배 (88.6%)
# ❌ medium_clean_278_aug_48241a37.jpg 예측 실패: 400
# {'code': 'BadRequestImageSizeBytes', 'message': '9bd80cf1662e4ff1b49c7e93627925f4: 5693627/4194304 bytes'}
# 📂 medium_clean_279.jpg → 🧠 담배 (97.2%)
# ❌ medium_clean_279_aug_16b64c92.jpg 예측 실패: 400
# {'code': 'BadRequestImageSizeBytes', 'message': 'ab694ae2f9624f3cbb2650b9f66ffbe4: 5511096/4194304 bytes'}
# ❌ medium_clean_279_aug_a12d6296.jpg 예측 실패: 400
# {'code': 'BadRequestImageSizeBytes', 'message': '5933dcfa45fb44ffb0c937eab18c0ff4: 5295836/4194304 bytes'}
# ❌ medium_clean_279_aug_e2e1048f.jpg 예측 실패: 400
# {'code': 'BadRequestImageSizeBytes', 'message': '590c74d8c3834750bf8ce99cdf77d73f: 13025616/4194304 bytes'}
# 📂 medium_clean_280.jpg → 🧠 담배 (86.5%)
# ❌ medium_clean_280_aug_020aea81.jpg 예측 실패: 400
# {'code': 'BadRequestImageSizeBytes', 'message': '7375eac4a64e48b4a29bec50538a793f: 5385375/4194304 bytes'}
# 📂 medium_clean_281.jpg → 🧠 담배 (93.0%)
# ❌ medium_clean_281_aug_18c62ff3.jpg 예측 실패: 400
# {'code': 'BadRequestImageSizeBytes', 'message': '323635a32923497da2000ea3f6f63bd8: 4989659/4194304 bytes'}
# 📂 medium_clean_284.jpg → 🧠 담배 (97.6%)
# ❌ medium_clean_284_aug_21e356b7.jpg 예측 실패: 400
# {'code': 'BadRequestImageSizeBytes', 'message': 'b4f0d9de7ace4aafbec090e586bafed3: 5374679/4194304 bytes'}
# ❌ medium_clean_284_aug_42c7ae2c.jpg 예측 실패: 400
# {'code': 'BadRequestImageSizeBytes', 'message': '6d50adfa3c2e4b66b2607817926dca82: 15062701/4194304 bytes'}
# 📂 medium_heavy_061.jpg → 🧠 담배 (30.9%)
# 📂 medium_heavy_061_aug_386883af.jpg → 🧠 담배 (44.9%)
# 📂 medium_heavy_061_aug_81078575.jpg → 🧠 담배 (65.4%)
# ❌ medium_heavy_061_aug_951a9171.jpg 예측 실패: 400
# {'code': 'BadRequestImageSizeBytes', 'message': 'd4128b6ecc684901bdc5cf1f0a50b343: 11650238/4194304 bytes'}
# 📂 medium_heavy_061_aug_b5790acb.jpg → 🧠 담배 (94.9%)
# 📂 medium_heavy_063.jpg → 🧠 담배 (13.7%)
# 📂 medium_heavy_063_aug_2ac46802.jpg → 🧠 담배 (10.9%)
# ❌ medium_heavy_063_aug_4397f5d3.jpg 예측 실패: 400
# {'code': 'BadRequestImageSizeBytes', 'message': 'a8d900c25f3548b09934a87a59428397: 9249353/4194304 bytes'}
# ❌ medium_heavy_063_aug_5ac08db3.jpg 예측 실패: 400
# {'code': 'BadRequestImageSizeBytes', 'message': 'a53ef0b4a88c4561b15a262b130fcb22: 10970789/4194304 bytes'}
# 📂 medium_heavy_063_aug_d5410780.jpg → 🧠 담배 (13.3%)
# 📂 medium_heavy_068.jpg → 🧠 담배 (98.1%)
# 📂 medium_heavy_068_aug_2bad0ebd.jpg → 🧠 담배 (16.2%)
# 📂 medium_heavy_068_aug_5b7756ad.jpg → 🧠 담배 (93.7%)
# 📂 medium_heavy_070.jpg → 🧠 담배 (57.6%)
# 📂 medium_heavy_070_aug_5e8bb178.jpg → 🧠 담배 (50.9%)
# 📂 medium_heavy_070_aug_71770092.jpg → 🧠 담배 (96.5%)
# 📂 news-p.v1.20231115.a92a83b277bc4f0c82fcd6203b6fc7e5_P2.jpg → 🧠 담배 (93.6%)
# 📂 news-p.v1.20231115.a92a83b277bc4f0c82fcd6203b6fc7e5_P2_aug_3e3cf7e1.jpg → 🧠 담배 (20.6%)
# 📂 news-p.v1.20231115.a92a83b277bc4f0c82fcd6203b6fc7e5_P2_aug_8438aec5.jpg → 🧠 담배 (40.7%)
# 📂 news_1688621280_1250697_m_1.jpg → 🧠 담배 (99.7%)
# 📂 news_1688621280_1250697_m_1_aug_6c00966d.jpg → 🧠 담배 (98.3%)
# 📂 news_1718603323_1372659_m_3.jpg → 🧠 담배 (60.9%)
# 📂 news_1718603323_1372659_m_3_aug_b1e5f04f.jpg → 🧠 담배 (47.0%)
# 📂 sosp_KV_17888_20240826_110634.jpg → 🧠 담배 (53.6%)
# 📂 sosp_KV_17888_20240826_110634_aug_6dcfc22b.jpg → 🧠 담배 (19.9%)
# 📂 sosp_KV_17888_20240826_110634_aug_e83428b9.jpg → 🧠 담배 (93.9%)
# 📂 sosp_KV_25051_20240707_170406.jpg → 🧠 담배 (8.8%)
# 📂 sosp_KV_25051_20240707_170406_aug_0df7caa4.jpg → 🧠 담배 (33.8%)
# 📂 sosp_KV_25051_20240707_170406_aug_f2346455.jpg → 🧠 담배 (57.5%)
# 📂 sosp_KV_25866_20240831_194055.jpg → 🧠 담배 (62.8%)
# 📂 sosp_KV_25866_20240831_194055_aug_29090386.jpg → 🧠 담배 (69.2%)
# 📂 thumb_d_BCDE1B716DC67E11916D9B699C794B20.jpg → 🧠 담배 (99.8%)
# 📂 thumb_d_BCDE1B716DC67E11916D9B699C794B20_aug_54b2135b.jpg → 🧠 담배 (98.9%)
# 📂 thumb_d_BCDE1B716DC67E11916D9B699C794B20_aug_afe8d99d.jpg → 🧠 담배 (99.0%)
# 📂 thumb_d_BCDE1B716DC67E11916D9B699C794B20_aug_c2460a4e.jpg → 🧠 담배 (99.5%)
# 📂 다운로드 (1).jpg → 🧠 담배 (98.6%)
# 📂 다운로드 (10).jpg → 🧠 담배 (30.4%)
# 📂 다운로드 (11).jpg → 🧠 담배 (78.2%)
# 📂 다운로드 (12).jpg → 🧠 담배 (99.8%)
# 📂 다운로드 (13).jpg → 🧠 담배 (67.6%)
# 📂 다운로드 (14).jpg → 🧠 담배 (74.4%)
# 📂 다운로드 (15).jpg → 🧠 담배 (99.1%)
# 📂 다운로드 (16).jpg → 🧠 담배 (88.5%)
# 📂 다운로드 (17).jpg → 🧠 담배 (98.8%)
# 📂 다운로드 (18).jpg → 🧠 담배 (98.6%)
# 📂 다운로드 (19).jpg → 🧠 담배 (97.6%)
# 📂 다운로드 (2).jpg → 🧠 담배 (94.8%)
# 📂 다운로드 (20).jpg → 🧠 담배 (92.7%)
# 📂 다운로드 (21).jpg → 🧠 담배 (96.3%)
# 📂 다운로드 (22).jpg → 🧠 담배 (57.0%)
# 📂 다운로드 (23).jpg → 🧠 담배 (83.4%)
# 📂 다운로드 (24).jpg → 🧠 담배 (93.0%)
# 📂 다운로드 (25).jpg → 🧠 담배 (99.2%)
# 📂 다운로드 (26).jpg → 🧠 담배 (94.9%)
# 📂 다운로드 (28).jpg → 🧠 담배 (99.4%)
# 📂 다운로드 (29).jpg → 🧠 담배 (30.7%)
# 📂 다운로드 (3).jpg → 🧠 담배 (70.0%)
# 📂 다운로드 (31).jpg → 🧠 담배 (78.3%)
# 📂 다운로드 (32).jpg → 🧠 담배 (81.7%)
# 📂 다운로드 (33).jpg → 🧠 담배 (80.4%)
# 📂 다운로드 (34).jpg → 🧠 담배 (84.5%)
# 📂 다운로드 (35).jpg → 🧠 담배 (93.5%)
# 📂 다운로드 (36).jpg → 🧠 담배 (98.9%)
# 📂 다운로드 (37).jpg → 🧠 담배 (79.2%)
# 📂 다운로드 (38).jpg → 🧠 담배 (89.1%)
# 📂 다운로드 (39).jpg → 🧠 담배 (99.5%)
# 📂 다운로드 (4).jpg → 🧠 담배 (98.7%)
# 📂 다운로드 (40).jpg → 🧠 담배 (97.8%)
# 📂 다운로드 (41).jpg → 🧠 담배 (21.5%)
# 📂 다운로드 (42).jpg → 🧠 담배 (95.8%)
# 📂 다운로드 (5).jpg → 🧠 담배 (99.7%)
# 📂 다운로드 (6).jpg → 🧠 담배 (25.5%)
# 📂 다운로드 (7).jpg → 🧠 담배 (95.4%)
# 📂 다운로드 (8).jpg → 🧠 담배 (98.5%)
# 📂 다운로드 (9).jpg → 🧠 담배 (8.4%)
# 📂 다운로드.jpg → 🧠 담배 (83.9%)
# 📂 사진_001.jpg → 🧠 담배 (97.8%)
# 📂 스크린샷 2025-06-11 214317.jpg → 🧠 담배 (100.0%)
# 📂 스크린샷 2025-06-11 220638.jpg → 🧠 담배 (98.8%)

# %%
# iteration 6
import os
import requests

# === [Azure Custom Vision 설정] ===
prediction_key = "BBvYKDdr5RDpSMjG34Z2XXw3hLxzlAQkktCPXwHTLleSagQPHGg0JQQJ99BEACYeBjFXJ3w3AAAIACOGH9bC"
prediction_url = "https://7aiteam05cv-prediction.cognitiveservices.azure.com/customvision/v3.0/Prediction/e81e8daf-2a54-4f41-9c8f-581d45e49ee9/detect/iterations/Iteration6/image"

# === [예측할 이미지 폴더 경로] ===
image_folder = "hyunjinim"  # 예: "C:/Users/USER/Desktop/images"

headers = {
    "Prediction-Key": prediction_key,
    "Content-Type": "application/octet-stream"
}

# === [이미지 반복 예측] ===
for filename in sorted(os.listdir(image_folder)):
    if not filename.lower().endswith(".jpg"):
        continue

    filepath = os.path.join(image_folder, filename)

    with open(filepath, "rb") as image_file:
        response = requests.post(prediction_url, headers=headers, data=image_file.read())

    if response.status_code == 200:
        predictions = response.json()["predictions"]
        top_pred = max(predictions, key=lambda x: x["probability"])
        print(f"📂 {filename} → 🧠 {top_pred['tagName']} ({top_pred['probability'] * 100:.1f}%)")
    else:
        print(f"❌ {filename} 예측 실패: {response.status_code}")
        print(response.json())
# Out:
# 📂 1000_F_179152264_oDXn15H5rlVA8vVIOLYOtEFjJ3YE6PGk.jpg → 🧠 노담배 (96.3%)
# 📂 1000_F_684270486_MeMtki9NSHi9T2V1keW1m7SmotxECAYZ.jpg → 🧠 노담배 (65.9%)
# 📂 1000_F_753254029_GHk60JCMY4Db6r54d8buaml03ZpcIxos.jpg → 🧠 담배 (95.4%)
# 📂 14985_0_kreidestifte_weiss_3867_1.jpg → 🧠 담배 (67.2%)
# 📂 20230809164700.jpg → 🧠 노담배 (98.7%)
# 📂 210035335_2673303816295580_1193481950564222526_n_2673303809628914.jpg → 🧠 노담배 (94.4%)
# 📂 2C019A4E00000578-3223659-image-a-132_1441484254621.jpg → 🧠 노담배 (98.7%)
# 📂 360_F_140812068_mS7tgAPjPyfsgYvDYdWoz47JJAqpo1ZQ.jpg → 🧠 담배 (89.9%)
# 📂 360_F_249912892_x0kuGCp2V8xnXHGmJtbYNHO3HptJDIB1.jpg → 🧠 담배 (73.7%)
# 📂 360_F_275857085_kML60FnaVOKlpLt6JAlknf8R24nnkQsK.jpg → 🧠 노담배 (93.9%)
# 📂 360_F_515688505_7W4Bm2efOgMwxhoUqKlZ0ZQFkXbOTLtF.jpg → 🧠 노담배 (91.6%)
# 📂 360_F_540417071_xy2zyYXDrxeMgnNtGZl8YgAZKJhIklTx.jpg → 🧠 노담배 (51.5%)
# 📂 41Qkx3v4AwL.__AC_SX300_SY300_QL70_ML2_.jpg → 🧠 담배 (15.4%)
# 📂 4967718948504_t.jpg → 🧠 담배 (61.1%)
# 📂 500_F_109927440_Kv8K4RIVsPv7Eprznfwjk2nSus3QxEq8.jpg → 🧠 노담배 (94.4%)
# 📂 500_F_134522959_4v9sSrjuET8rTwqrCYNe3xUteLxAOgWJ.jpg → 🧠 노담배 (84.5%)
# 📂 52472015711_4b047be679_b.jpg → 🧠 노담배 (93.8%)
# 📂 5d0ef8848daaf76d5ee5023f5c512612_w.jpg → 🧠 노담배 (99.2%)
# 📂 7310009088_15b5c23ffa.jpg → 🧠 노담배 (96.3%)
# 📂 7ed602002ec344dbbdf376eb42375956-e1679640414201.jpg → 🧠 노담배 (99.1%)
# 📂 7fc5ef8829b3a8ebfb28e6eae5b7fd85_w.jpg → 🧠 노담배 (97.2%)
# 📂 8-2-1024x682.jpg → 🧠 노담배 (99.0%)
# 📂 823a4fc27910300c5f59c1d4de850c3b.jpg → 🧠 노담배 (54.5%)
# 📂 A (13).jpg → 🧠 노담배 (96.9%)
# 📂 Comment-faire-un-bon-drainage-autour-dune-maison-.jpg → 🧠 노담배 (96.4%)
# 📂 DSCN3083.jpg → 🧠 담배 (67.1%)
# 📂 OIP (1).jpg → 🧠 담배 (94.9%)
# 📂 OIP (10).jpg → 🧠 노담배 (99.4%)
# 📂 OIP (11).jpg → 🧠 노담배 (73.9%)
# 📂 OIP (12).jpg → 🧠 노담배 (6.2%)
# 📂 OIP (13).jpg → 🧠 노담배 (97.3%)
# 📂 OIP (14).jpg → 🧠 담배 (58.7%)
# 📂 OIP (15).jpg → 🧠 노담배 (82.5%)
# 📂 OIP (16).jpg → 🧠 담배 (32.2%)
# 📂 OIP (17).jpg → 🧠 담배 (89.6%)
# 📂 OIP (18).jpg → 🧠 노담배 (78.6%)
# 📂 OIP (19).jpg → 🧠 노담배 (99.2%)
# 📂 OIP (2).jpg → 🧠 담배 (94.3%)
# 📂 OIP (20).jpg → 🧠 노담배 (97.7%)
# 📂 OIP (21).jpg → 🧠 노담배 (95.9%)
# 📂 OIP (22).jpg → 🧠 노담배 (95.5%)
# 📂 OIP (23).jpg → 🧠 노담배 (86.2%)
# 📂 OIP (24).jpg → 🧠 노담배 (68.7%)
# 📂 OIP (25).jpg → 🧠 노담배 (92.8%)
# 📂 OIP (26).jpg → 🧠 노담배 (74.3%)
# 📂 OIP (27).jpg → 🧠 노담배 (90.1%)
# 📂 OIP (28).jpg → 🧠 담배 (96.2%)
# 📂 OIP (29).jpg → 🧠 노담배 (98.3%)
# 📂 OIP (3).jpg → 🧠 노담배 (24.2%)
# 📂 OIP (30).jpg → 🧠 노담배 (83.4%)
# 📂 OIP (31).jpg → 🧠 노담배 (98.8%)
# 📂 OIP (32).jpg → 🧠 노담배 (91.3%)
# 📂 OIP (33).jpg → 🧠 노담배 (94.9%)
# 📂 OIP (34).jpg → 🧠 노담배 (90.3%)
# 📂 OIP (35).jpg → 🧠 노담배 (80.9%)
# 📂 OIP (4).jpg → 🧠 노담배 (93.9%)
# 📂 OIP (5).jpg → 🧠 노담배 (84.6%)
# 📂 OIP (6).jpg → 🧠 노담배 (77.7%)
# 📂 OIP (8).jpg → 🧠 노담배 (99.4%)
# 📂 OIP (9).jpg → 🧠 노담배 (99.9%)
# 📂 OIP.jpg → 🧠 담배 (87.4%)
# 📂 R (1).jpg → 🧠 노담배 (91.2%)
# 📂 R (2).jpg → 🧠 노담배 (99.1%)
# 📂 R (3).jpg → 🧠 노담배 (82.9%)
# 📂 R (4).jpg → 🧠 담배 (70.7%)
# 📂 R (5).jpg → 🧠 노담배 (96.5%)
# 📂 R (6).jpg → 🧠 노담배 (91.7%)
# 📂 R (7).jpg → 🧠 노담배 (79.1%)
# 📂 R.jpg → 🧠 노담배 (95.0%)
# 📂 Sinkkastenreinigung.jpg → 🧠 담배 (88.0%)
# 📂 Storm_Drain_Dryden.jpg → 🧠 노담배 (81.9%)
# 📂 a-drain-in-a-school-with-such-bad-positioning-it-is-v0-z3780jwtgd0a1.jpg → 🧠 담배 (95.4%)
# 📂 c7788.jpg → 🧠 노담배 (97.7%)
# 📂 caditoie sant'angelo in formis1.jpg → 🧠 노담배 (62.9%)
# 📂 close-up-shot-pine-cone-close-up-shot-pine-cone-laying-ground-borsec-harghita-romania-292455412.jpg → 🧠 노담배 (84.0%)
# 📂 closeup-group-pine-cones-eaten-squirrels-some-crunched-well-aligned-granite-stone-141887205.jpg → 🧠 담배 (89.6%)
# 📂 crumpled-paper-20183819.jpg → 🧠 담배 (87.1%)
# 📂 crumpled-paper-balls-realistic-garbage-600w-1912170124.jpg → 🧠 담배 (59.8%)
# 📂 depositphotos_13736667-stock-photo-paper-ball-crumpled-garbage-frustration.jpg → 🧠 노담배 (51.0%)
# 📂 dfd75c2c6272405d31ddd5c8f5987071_w.jpg → 🧠 노담배 (91.4%)
# 📂 drain-grate-garbage-on-260nw-420228460.jpg → 🧠 담배 (70.0%)
# 📂 drain-grate-garbage-on-it-260nw-2244845057.jpg → 🧠 노담배 (84.3%)
# 📂 ede06127-703d-4ca2-90ba-4ae479576173_m.jpg → 🧠 노담배 (96.3%)
# 📂 grate-cracked-cement-around-sits-260nw-2231753727.jpg → 🧠 노담배 (96.3%)
# 📂 hot-melt-glue-stick-118.jpg → 🧠 담배 (59.7%)
# 📂 image-asset.jpg → 🧠 노담배 (91.6%)
# 📂 image.jpg → 🧠 노담배 (95.3%)
# 📂 img-pozzetti-3-575x382.jpg → 🧠 노담배 (66.8%)
# 📂 istockphoto-1179568768-612x612.jpg → 🧠 담배 (77.9%)
# 📂 large.jpg → 🧠 담배 (98.6%)
# 📂 manhole-in-rome-1564050.jpg → 🧠 노담배 (97.5%)
# 📂 news-p.v1.20240606.6594109fd0a24845b8b324d2a421b755_P1.jpg → 🧠 담배 (99.9%)
# 📂 paper-ball-crumpled-EJJ9JR.jpg → 🧠 노담배 (82.0%)
# 📂 pine-corn-pinecone-fell-down-one-ground-wood-sequoia-national-park-soft-brown-tone-blank-space-112876839.jpg → 🧠 노담배 (92.6%)
# 📂 storm-drain-grate-cracked-asphalt-rusty-storm-drain-grate-cracked-asphalt-219429889.jpg → 🧠 노담배 (93.2%)
# 📂 thumbnail_large-1.jpg → 🧠 노담배 (85.6%)
# 📂 white_stick_0.jpg → 🧠 담배 (76.8%)

# %%
# iteration 7
import os
import requests

# === [Azure Custom Vision 설정] ===
prediction_key = "BBvYKDdr5RDpSMjG34Z2XXw3hLxzlAQkktCPXwHTLleSagQPHGg0JQQJ99BEACYeBjFXJ3w3AAAIACOGH9bC"
prediction_url = "https://7aiteam05cv-prediction.cognitiveservices.azure.com/customvision/v3.0/Prediction/e81e8daf-2a54-4f41-9c8f-581d45e49ee9/detect/iterations/Iteration7/image"

# === [예측할 이미지 폴더 경로] ===
image_folder = "0613ciga_test2"  # 예: "C:/Users/USER/Desktop/images"

headers = {
    "Prediction-Key": prediction_key,
    "Content-Type": "application/octet-stream"
}

# === [이미지 반복 예측] ===
for filename in sorted(os.listdir(image_folder)):
    if not filename.lower().endswith(".jpg"):
        continue

    filepath = os.path.join(image_folder, filename)

    with open(filepath, "rb") as image_file:
        response = requests.post(prediction_url, headers=headers, data=image_file.read())

    if response.status_code == 200:
        predictions = response.json()["predictions"]
        top_pred = max(predictions, key=lambda x: x["probability"])
        print(f"📂 {filename} → 🧠 {top_pred['tagName']} ({top_pred['probability'] * 100:.1f}%)")
    else:
        print(f"❌ {filename} 예측 실패: {response.status_code}")
        print(response.json())
# Out:
# 📂 360_F_311285826_hpnEQj8txKtX5mCl4K7oHH4lkGuRxXvU.jpg → 🧠 노담배 (98.8%)
# 📂 360_F_473057378_dvyrCRb7ZlOy0E8witgFIF6fkYw8LI0r.jpg → 🧠 노담배 (99.3%)
# 📂 3df993938ec00a4fa2b5fc545e4d4a7b0975537f.71.9.9.3.jpg → 🧠 노담배 (98.6%)
# 📂 4429bdc8f4bed76d1d63907a2008bfbd-1536x864.jpg → 🧠 노담배 (92.2%)
# 📂 OIP (1).jpg → 🧠 노담배 (97.9%)
# 📂 OIP (2).jpg → 🧠 노담배 (99.6%)
# 📂 OIP.jpg → 🧠 노담배 (99.6%)
# 📂 R (1).jpg → 🧠 담배 (99.5%)
# 📂 R.jpg → 🧠 노담배 (97.8%)
# 📂 drain5.jpg → 🧠 노담배 (96.3%)
# 📂 imgdac05e8dzik0zj.jpg → 🧠 노담배 (99.1%)
# 📂 o1080116614786240065.jpg → 🧠 노담배 (99.2%)
# 📂 o2304129614627900845.jpg → 🧠 노담배 (99.3%)
# 📂 tsdr-pl-pipe230618t-5.jpg → 🧠 노담배 (94.4%)
